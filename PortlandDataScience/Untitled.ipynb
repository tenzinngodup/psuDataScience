# %%
import pandas as pd

# %%
df = pd.read_csv("stocks-us-adjClose.csv")
df.head()
# Out:
#   compiled from Yahoo! Finance data by Matt Borthwick        ED        DD  \
# 0                                         1970-01-02   0.307997  0.000480
# 1                                         1970-01-05   0.320831  0.000481
# 2                                         1970-01-06   0.316553  0.000477
# 3                                         1970-01-07   0.312275  0.000475
# 4                                         1970-01-08   0.312275  0.000469
#
#         CVX        FL       CAT        IP  SJW   F  LLY ...   EXTN  VYGR  ACG  \
# 0  0.582503  1.857836  1.475225  1.808415  NaN NaN  NaN ...    NaN   NaN  NaN
# 1  0.585290  1.839623  1.470783  1.873423  NaN NaN  NaN ...    NaN   NaN  NaN
# 2  0.576929  1.845694  1.435234  1.855694  NaN NaN  NaN ...    NaN   NaN  NaN
# 3  0.575535  1.809266  1.390800  1.814324  NaN NaN  NaN ...    NaN   NaN  NaN
# 4  0.586683  1.821408  1.395244  1.832054  NaN NaN  NaN ...    NaN   NaN  NaN
#
#    MIME  TCRZ  MCX  EDIT  LMHA  UA  BTU
# ...

# %%
df.describe()
# Out:
#                  ED            DD           CVX            FL           CAT  \
# count  12032.000000  12031.000000  12032.000000  12032.000000  12032.000000
# mean      16.221365      4.657988     25.838805     13.652820     22.134786
# std       19.088316     16.842472     32.410597     15.029301     28.448792
# min        0.092676      0.000419      0.443472      0.505457      1.075315
# 25%        0.980461      0.000945      2.323380      2.445677      2.826035
# 50%        8.586078      0.003967      9.601468     10.450088      5.716164
# 75%       25.608041      0.014223     38.221566     16.793522     32.422255
# max       85.529999     85.106949    117.790649     78.051933    118.300003
#
#                  IP           SJW             F           LLY           AVP  \
# count  12032.000000  11420.000000  11420.000000  11420.000000  11420.000000
# mean      16.284163      9.438188      5.889809     21.605734      9.268025
# ...

# %%
df.plot()
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt(df['compiled from Yahoo! Finance data by Matt Borthwick'],df['ED'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5312d789325c> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 plt(df['compiled from Yahoo! Finance data by Matt Borthwick'],df['ED'])
#
# TypeError: 'module' object is not callable

# %%
df.tail()
# Out:
#       compiled from Yahoo! Finance data by Matt Borthwick         ED  \
# 12027                                         2017-09-01   83.989998
# 12028                                         2017-09-05   84.370003
# 12029                                         2017-09-06   84.050003
# 12030                                         2017-09-07   84.739998
# 12031                                         2017-09-08   85.529999
#
#               DD         CVX         FL         CAT         IP        SJW  \
# 12027        NaN  108.760002  36.340000  118.279999  54.910000  55.080002
# 12028  44.799999  109.440002  36.330002  118.300003  54.790001  55.720001
# 12029  44.849998  111.790001  36.700001  116.980003  54.880001  55.900002
# 12030  44.099998  111.800003  36.160000  117.769997  54.689999  56.360001
# 12031  43.500000  110.779999  35.730000  117.820000  54.779999  56.709999
#
#            F        LLY    ...       VYGR  ACG       MIME       TCRZ  \
# ...

# %%
# import seaborn as sns
# ax = sns.tsplot(time="newDT", value="ED", data=df)

# %%
from datetime import datetime

def formatDatetime(x): 
    return datetime.strptime(x, '%Y-%m-%d')
df['newDT'] = df['compiled from Yahoo! Finance data by Matt Borthwick'].apply(formatDatetime)

# %%
# import matplotlib
# matplotlib.pyplot.plot_date(df['newDT'], df['ED'])

df.plot(x="newDT", y=["ED",'DD','CVX','FL','CAT'], kind="line")
# Out:
# /Users/tngodup/miniconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
# import matplotlib
# matplotlib.pyplot.plot_date(df['newDT'], df['ED'])
import numpy as np
df['newED'] = df['ED'].apply(np.log)
df['newDD'] = df['DD'].apply(np.log)
df['newCVX'] = df['CVX'].apply(np.log)
df['newFL'] = df['FL'].apply(np.log)
df['newCAT'] = df['CAT'].apply(np.log)

df.plot(x="newDT", y=["newED",'newDD','newCVX','newFL','newCAT'], kind="line")
# Out:
# /Users/tngodup/miniconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
from economics import Inflation
import datetime
# Create a new Inflation instance
inflation = Inflation()
# How many US $ would I need in 2011 to pay for what cost $5 in 2007
inflation.inflate(5, datetime.date(2011,1,1), datetime.date(2007,1,1), 'United States')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-ff9ca2baba04> in <module>()
# ----> 1 from economics import Inflation
#       2 import datetime
#       3 # Create a new Inflation instance
#       4 inflation = Inflation()
#       5 # How many US $ would I need in 2011 to pay for what cost $5 in 2007
#
# ~/miniconda3/lib/python3.6/site-packages/economics/__init__.py in <module>()
# ----> 1 from cpi import CPI
#       2 from inflation import Inflation
#
# ModuleNotFoundError: No module named 'cpi'

# %%
from economics import cpi
import datetime
# Create a new CPI instance
cpi = CPI()

# Get CPI for Iceland in 2007
cpi.get(datetime.date(2007,1,1), 'Iceland')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-7c39988de4c6> in <module>()
# ----> 1 from economics import cpi
#       2 import datetime
#       3 # Create a new CPI instance
#       4 cpi = CPI()
#       5
#
# ~/miniconda3/lib/python3.6/site-packages/economics/__init__.py in <module>()
# ----> 1 from cpi import CPI
#       2 from inflation import Inflation
#
# ModuleNotFoundError: No module named 'cpi'

# %%
from easymoney.money import EasyPeasy
ep = EasyPeasy()
ep.normalize(amount = 100,  from_year = 2010, to_year = "latest", base_currency = "CAD", pretty_print = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2b64789faa52> in <module>()
#       1 from easymoney.money import EasyPeasy
#       2 ep = EasyPeasy()
# ----> 3 ep.normalize(amount = 100,  from_year = 2010, to_year = "latest", base_currency = "CAD", pretty_print = True)
#
# TypeError: normalize() missing 1 required positional argument: 'region'
