# %%
from IPython.display import Image
Image(filename='maxresdefault.jpg', width=420)

# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = ResNet50(weights='2fefdb45-9b31-45c6-a714-dc76f8576c6b_resnet50_weights_tf_dim_ordering_tf_kernels.h5')

img_path = 'maxresdefault.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ...
# 40960/35363 [==================================] - 0s 5us/step
# Predicted: [('n02099601', 'golden_retriever', 0.96625614), ('n02099712', 'Labrador_retriever', 0.020732107), ('n02088094', 'Afghan_hound', 0.0035725369)]

# %%
Image(filename='Golden-Retriever-2.jpg', width=420) 

img_path = 'Golden-Retriever-2.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02099601', 'golden_retriever', 0.8471766), ('n02100877', 'Irish_setter', 0.13378586), ('n02102318', 'cocker_spaniel', 0.007112082)]

# %%
Image(filename='donald.jpg', width=420) 

img_path = 'donald.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04350905', 'suit', 0.9739966), ('n04591157', 'Windsor_tie', 0.018148627), ('n10148035', 'groom', 0.0041767363)]
